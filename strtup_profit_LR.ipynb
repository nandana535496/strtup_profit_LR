# %%
#Problem Statement:You are given data from 50 startups across the U.S. with the goal of predicting a startup’s profit based on the some features:

# %%
#objective:  build a linear regression model to estimate the expected profit, and explore which features contribute most to the business success.
import pandas as pd

# %%
#load the data_set
df=pd.read_csv("Downloads/archive (2).zip")
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
# One-Hot Encode the 'State' column
df = pd.get_dummies(df, columns=['State'], drop_first=True)

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit  State_Florida  \
# 0   165349.20       136897.80        471784.10  192261.83          False
# 1   162597.70       151377.59        443898.53  191792.06          False
# 2   153441.51       101145.55        407934.54  191050.39           True
# 3   144372.41       118671.85        383199.62  182901.99          False
# 4   142107.34        91391.77        366168.42  166187.94           True
# 5   131876.90        99814.71        362861.36  156991.12          False
# 6   134615.46       147198.87        127716.82  156122.51          False
# 7   130298.13       145530.06        323876.68  155752.60           True
# 8   120542.52       148718.95        311613.29  152211.77          False
# 9   123334.88       108679.17        304981.62  149759.96          False
# 10  101913.08       110594.11        229160.95  146121.95           True
# 11  100671.96        91790.61        249744.55  144259.40          False
# ...

# %%
x=df.drop(['Profit'],axis=1)
y=df.Profit

# %%
#Train/Test Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#Build the Linear Regression Model
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#prediction
y_pred=lr.predict(X_test)
print(y_pred)
# Out:
# [126362.87908255  84608.45383634  99677.49425147  46357.46068582
#  128750.48288504  50912.4174188  109741.35032702 100643.24281647
#   97599.27574594 113097.42524432]

# %%
# Evaluate the Model
from sklearn.metrics import mean_squared_error,r2_score
print(f'RMSE{mean_squared_error(y_test,y_pred)}')
print(f'r2_score{r2_score(y_test,y_pred)}')
# Out:
# RMSE82010363.04430106
# r2_score0.8987266414328636

# %%
coeff_df = pd.DataFrame(lr.coef_, x.columns, columns=['Coefficient'])
print(coeff_df)
# Out:
#                  Coefficient
# R&D Spend           0.805630
# Administration     -0.068788
# Marketing Spend     0.029855
# State_Florida     938.793006
# State_New York      6.987760

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(6, 6))
sns.scatterplot(x=y_test, y=y_pred)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'red')

plt.xlabel("Actual Profit")
plt.ylabel("Predicted Profit")
plt.title("Actual vs Predicted Profit")
plt.grid(True)
plt.show()

# %%
residuals = y_test - y_pred
plt.figure(figsize=(8, 4))
sns.histplot(residuals,  bins=30, color="purple")
plt.title("Distribution of Residuals")
plt.xlabel("Residual")
plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.regplot(x=df["R&D Spend"], y=df["Profit"], scatter_kws={"color": "blue"}, line_kws={"color": "red"})
plt.title("Profit vs R&D Spend")
plt.xlabel("R&D Spend")
plt.ylabel("Profit")
plt.grid(True)
plt.show()

# %%
corr = df.corr()

# Plot the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()

# %%
#coclusions :
'''The most important factor affecting Profit is R&D Spend.
Higher investment in research and development leads to higher profit,
more than marketing or administrative spending.
'''
# Out:
# 'The most important factor affecting Profit is R&D Spend.\nHigher investment in research and development leads to higher profit,\nmore than marketing or administrative spending.\n'
